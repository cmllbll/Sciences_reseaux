# %%
import json
import pandas as pd
import networkx as nx
from networkx.algorithms import community
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Data
f = open(r'../congress_network/congress_network_data.json')
data = json.load(f)

inList = data[0]['inList']
inWeight = data[0]['inWeight']
outList = data[0]['outList']
outWeight = data[0]['outWeight']
usernameList = data[0]['usernameList']

# Attributs
attributes_df = pd.read_csv('../congress_network/congress_member_attributes.csv')
def recode_age(age) :
    if age<40 :
        return "Moins de 40 ans"
    elif age<50:
        return "40 à 49 ans"
    elif age<60:
        return "50 à 59 ans"
    elif age<70:
        return "60 à 69 ans"
    elif age<80:
        return "70 à 79 ans"
    else:
        return "Plus de 80 ans"
attributes_df["age_recode"] = attributes_df["age"].apply(recode_age)

# %%
attributes_df
# Out:
#      congress_member sex  age party chamber   age_recode
# 0     SenatorBaldwin   F   60     D       S  60 à 69 ans
# 1    SenJohnBarrasso   H   70     R       S  70 à 79 ans
# 2      SenatorBennet   H   60     D       S  60 à 69 ans
# 3    MarshaBlackburn   F   70     R       S  70 à 79 ans
# 4      SenBlumenthal   H   76     D       S  70 à 79 ans
# ..               ...  ..  ...   ...     ...          ...
# 470     RepJoeWilson   H   75     R     Rep  70 à 79 ans
# 471       RobWittman   H   63     R     Rep  60 à 69 ans
# 472  rep_stevewomack   H   65     R     Rep  60 à 69 ans
# 473   RepJohnYarmuth   H   75     R     Rep  70 à 79 ans
# 474     RepLeeZeldin   H   42     R     Rep  40 à 49 ans
#
# [475 rows x 6 columns]

# %% [markdown]
# ### Analyse de centralité

# %%
# Calculer la centralité de degré entrant
in_degree_centrality = [len(in_list) for in_list in inList]

# Calculer la centralité basée sur le poids des connexions entrantes
in_weighted_centrality_mean = [sum(weights)/len(weights) if len(weights)!=0 else 0 for weights in inWeight]
in_weighted_centrality_sum = [sum(weights) for weights in inWeight]

# Trouver les indices des 5 membres les plus centraux en termes de degré entrant
top_5_in_degree_indices = sorted(range(len(in_degree_centrality)), key=lambda i: in_degree_centrality[i], reverse=True)[:5]

# Trouver les indices des 5 membres les plus influents en termes de poids des connexions entrantes
top_5_in_weighted_indices_mean = sorted(range(len(in_weighted_centrality_mean)), key=lambda i: in_weighted_centrality_mean[i], reverse=True)[:5]
top_5_in_weighted_indices_sum = sorted(range(len(in_weighted_centrality_sum)), key=lambda i: in_weighted_centrality_sum[i], reverse=True)[:5]

# Afficher les résultats
print("Les résultats suivants sont ceux qui retweet le plus\n")

print("Les 5 membres les plus centraux (basé sur le degré entrant) sont :")
for i in top_5_in_degree_indices:
    print(f"{usernameList[i]} (centralité de degré entrant = {in_degree_centrality[i]})")

print("\nLes 5 membres les plus influents (basé sur le poids des connexions entrantes) sont :")
for i in top_5_in_weighted_indices_mean:
    print(f"{usernameList[i]} (centralité basée sur le poids moyen = {in_weighted_centrality_mean[i]})")
    
print("\nLes 5 membres les plus influents (basé sur la somme des poids des connexions entrantes) sont :")
for i in top_5_in_weighted_indices_sum:
    print(f"{usernameList[i]} (centralité basée sur la somme des poids = {in_weighted_centrality_sum[i]})")
# Out:
# Les résultats suivants sont ceux qui retweet le plus
#
# Les 5 membres les plus centraux (basé sur le degré entrant) sont :
# GOPLeader (centralité de degré entrant = 127)
# RepFranklin (centralité de degré entrant = 121)
# RepJeffDuncan (centralité de degré entrant = 120)
# RepDonBeyer (centralité de degré entrant = 109)
# LeaderHoyer (centralité de degré entrant = 108)
#
# Les 5 membres les plus influents (basé sur le poids des connexions entrantes) sont :
# Kilili_Sablan (centralité basée sur le poids moyen = 0.014388489208633094)
# GOPLeader (centralité basée sur le poids moyen = 0.012978594807167941)
# RepElaineLuria (centralité basée sur le poids moyen = 0.012934376308166514)
# RepChrisPappas (centralité basée sur le poids moyen = 0.012183560938419408)
# SenatorCardin (centralité basée sur le poids moyen = 0.012039653701156446)
#
# Les 5 membres les plus influents (basé sur la somme des poids des connexions entrantes) sont :
# GOPLeader (centralité basée sur la somme des poids = 1.6482815405103286)
# RepMikeJohnson (centralité basée sur la somme des poids = 0.9654453416856844)
# RepChipRoy (centralité basée sur la somme des poids = 0.951852893070543)
# RepFranklin (centralité basée sur la somme des poids = 0.8302262681069115)
# RepCasten (centralité basée sur la somme des poids = 0.814184782675911)

# %%
# Calculer la centralité de degré entrant
out_degree_centrality = [len(out_list) for out_list in outList]

# Calculer la centralité basée sur le poids des connexions entrantes
out_weighted_centrality_mean = [sum(weights)/len(weights) if len(weights)!=0 else 0 for weights in outWeight]
out_weighted_centrality_sum = [sum(weights) for weights in outWeight]

# Trouver les outdices des 5 membres les plus centraux en termes de degré entrant
top_5_out_degree_outdices = sorted(range(len(out_degree_centrality)), key=lambda i: out_degree_centrality[i], reverse=True)[:5]

# Trouver les outdices des 5 membres les plus outfluents en termes de poids des connexions entrantes
top_5_out_weighted_outdices_mean = sorted(range(len(out_weighted_centrality_mean)), key=lambda i: out_weighted_centrality_mean[i], reverse=True)[:5]
top_5_out_weighted_outdices_sum = sorted(range(len(out_weighted_centrality_sum)), key=lambda i: out_weighted_centrality_sum[i], reverse=True)[:5]

# Afficher les résultats
print("Les résultats suivants sont ceux qui sont le plus retweetés \n")

print("Les 5 membres les plus centraux (basé sur le degré entrant) sont :")
for i in top_5_out_degree_outdices:
    print(f"{usernameList[i]} (centralité de degré entrant = {out_degree_centrality[i]})")

print("\nLes 5 membres les plus influents (basé sur le poids des connexions sortantes) sont :")
for i in top_5_out_weighted_outdices_mean:
    print(f"{usernameList[i]} (centralité basée sur le poids moyen = {out_weighted_centrality_mean[i]})")
    
print("\nLes 5 membres les plus influents (basé sur la somme des poids des connexions sortantes) sont :")
for i in top_5_out_weighted_outdices_sum:
    print(f"{usernameList[i]} (centralité basée sur la somme des poids = {out_weighted_centrality_sum[i]})")
# Out:
# Les résultats suivants sont ceux qui sont le plus retweetés
#
# Les 5 membres les plus centraux (basé sur le degré entrant) sont :
# SpeakerPelosi (centralité de degré entrant = 210)
# GOPLeader (centralité de degré entrant = 157)
# RepBobbyRush (centralité de degré entrant = 111)
# SenSchumer (centralité de degré entrant = 97)
# SteveScalise (centralité de degré entrant = 89)
#
# Les 5 membres les plus influents (basé sur le poids des connexions sortantes) sont :
# RepSchrader (centralité basée sur le poids moyen = 0.027522935779816515)
# PatrickMcHenry (centralité basée sur le poids moyen = 0.021806853582554516)
# RepJoeWilson (centralité basée sur le poids moyen = 0.01829573934837092)
# CongBoyle (centralité basée sur le poids moyen = 0.01806451612903226)
# RepBobGood (centralité basée sur le poids moyen = 0.018018018018018018)
#
# Les 5 membres les plus influents (basé sur la somme des poids des connexions sortantes) sont :
# SpeakerPelosi (centralité basée sur la somme des poids = 0.9436392914653801)
# SteveScalise (centralité basée sur la somme des poids = 0.9351145038167934)
# RepBobbyRush (centralité basée sur la somme des poids = 0.8694158075601361)
# GOPLeader (centralité basée sur la somme des poids = 0.8272189349112421)
# RepJoeWilson (centralité basée sur la somme des poids = 0.695238095238095)

# %% [markdown]
# ### Analyse de communauté : représentant qui interragissent souvent ensemble

# %%
# Créer le graphe dirigé entrant
in_graph = nx.DiGraph()
for i, in_edges in enumerate(inList):
    for j, target in enumerate(in_edges):
        weight = inWeight[i][j]
        in_graph.add_edge(target, i, weight=weight)

# Créer le graphe dirigé sortant
out_graph = nx.DiGraph()
for i, out_edges in enumerate(outList):
    for j, target in enumerate(out_edges):
        weight = outWeight[i][j]
        out_graph.add_edge(i, target, weight=weight)

# Détecter les communautés dans le graphe dirigé entrant
in_communities = list(community.louvain_communities(in_graph, weight='weight'))

# Détecter les communautés dans le graphe dirigé sortant
out_communities = list(community.louvain_communities(out_graph, weight='weight'))

# Afficher les résultats des communautés détectées
print("\nCommunautés détectées dans le graphe dirigé entrant:")
for i, community_nodes in enumerate(in_communities):
    print(f"Communauté {i + 1}:")
    for node in community_nodes:
        print(f"  {usernameList[node]}")
    print()

print("\nCommunautés détectées dans le graphe dirigé sortant:")
for i, community_nodes in enumerate(out_communities):
    print(f"Communauté {i + 1}:")
    for node in community_nodes:
        print(f"  {usernameList[node]}")
    print()
# Out:
# Communautés détectées dans le graphe dirigé entrant:
# Communauté 1:
#   SenLummis
#   SenGillibrand
#
# Communauté 2:
#   MarshaBlackburn
#   SenBlumenthal
#   ChrisMurphyCT
#   CoryBooker
#   jahimes
#
# Communauté 3:
#   SenThomTillis
#   SenatorShaheen
#
# Communauté 4:
#   SenTinaSmith
#   SenAmyKlobuchar
#
# Communauté 5:
#   SenJoniErnst
#   ChuckGrassley
#
# Communauté 6:
#   SenatorHagerty
#   JohnCornyn
#
# Communauté 7:
#   SenatorWicker
#   SenHydeSmith
#
# Communauté 8:
#   lisamurkowski
#   Sen_JoeManchin
#   SenDanSullivan
#
# Communauté 9:
#   SenJohnBarrasso
#   SenatorRisch
#   SenJohnHoeven
#   JimInhofe
#   SenatorTimScott
#   SenCapito
#   SenatorSinema
#   SenMarkKelly
#   SenBillCassidy
#   SenJohnThune
#   SenToomey
#   SenKevinCramer
#   MikeCrapo
#   SenToddYoung
#   CongMikeSimpson
#
# Communauté 10:
#   SenatorBennet
#   SenatorHick
#
# Communauté 11:
#   timkaine
#   MarkWarner
#
# Communauté 12:
#   SenCortezMasto
#   RepSusieLee
#   SenJackyRosen
#   RepHorsford
#
# Communauté 13:
#   JerryMoran
#   SenatorTester
#
# Communauté 14:
#   RepPeterDeFazio
#   RepSchrader
#   SenJeffMerkley
#   RepBonamici
#   RepGregStanton
#   RonWyden
#
# Communauté 15:
#   RepCohen
#   SenatorRomney
#   Call_Me_Dutch
#   SenatorCardin
#   RepJohnCurtis
#   RepKweisiMfume
#   RepSarbanes
#   ChrisVanHollen
#   RepJoeWilson
#   RepMalinowski
#   LindseyGrahamSC
#
# Communauté 16:
#   SenTuberville
#   SenTomCotton
#   JohnBoozman
#
# Communauté 17:
#   RepRonnyJackson
#   RepMikeJohnson
#   HawleyMO
#   RepLaMalfa
#   RepDLesko
#   RandPaul
#   RepThomasMassie
#   RepBrianMast
#   RepLisaMcClain
#   RepMcKinley
#   RepMaryMiller
#   RepAlexMooney
#   RepBarryMoore
#   RepMullin
#   RepGregMurphy
#   RepRalphNorman
#   RepBrianBabin
#   RepBurgessOwens
#   CongPalazzo
#   RepJimBanks
#   RepAndyBiggsAZ
#   RepGusBilirakis
#   RepDanBishop
#   RepBoebert
#   RepMoBrooks
#   RepTomRice
#   RepJohnRose
#   RepRosendale
#   RepKenBuck
#   RepTedBudd
#   RepChipRoy
#   RepTimBurchett
#   RepDavidRouzer
#   RepKatCammack
#   RepCawthorn
#   AustinScottGA08
#   RepBenCline
#   RepCloudTX
#   Rep_Clyde
#   WarrenDavidson
#   RepGregSteube
#   RepTiffany
#   RepTimmons
#   RepDonaldsPress
#   RepJeffDuncan
#   DrNealDunnFL2
#   RepWalorski
#   RepChuck
#   RepWebster
#   RepFranklin
#   RepRussFulcher
#   RepMattGaetz
#   rep_stevewomack
#   RepBobGibbs
#   replouiegohmert
#   RepBobGood
#   Lancegooden
#   RepGosar
#   RepMarkGreen
#   RepMTG
#   RepGrothman
#   RepHarshbarger
#   RepHartzler
#   repkevinhern
#   CongressmanHice
#   RepClayHiggins
#
# Communauté 18:
#   SenRickScott
#   SenRonJohnson
#   SenJohnKennedy
#   marcorubio
#
# Communauté 19:
#   SenatorBraun
#   SenMikeLee
#   SenTedCruz
#   SenatorLankford
#
# Communauté 20:
#   senrobportman
#   SenSherrodBrown
#   RepTimRyan
#
# Communauté 21:
#   ChrisCoons
#   SenatorCarper
#   RepLBR
#
# Communauté 22:
#   MarioDB
#   RepCarlos
#   RepMariaSalazar
#   RepSires
#
# Communauté 23:
#   RepScottPeters
#   RepPaulTonko
#
# Communauté 24:
#   RoyBlunt
#   SenStabenow
#   SenGaryPeters
#
# Communauté 25:
#   JacksonLeeTX18
#   RepSaraJacobs
#   RepJeffries
#   RepEBJ
#   RepHankJohnson
#   SenBobCasey
#   RepRobinKelly
#   RepDanKildee
#   RepRonKind
#   RepKirkpatrick
#   SenatorFischer
#   JimLangevin
#   RepJohnLarson
#   RepLawrence
#   RepAlLawsonJr
#   RepTedLieu
#   RepSeanMaloney
#   RepKManning
#   DorisMatsui
#   RepLucyMcBath
#   BettyMcCollum04
#   RepMcGovern
#   RepGregoryMeeks
#   RepJerryNadler
#   gracenapolitano
#   RepAdams
#   RepRichardNeal
#   RepJoeNeguse
#   RepPeteAguilar
#   RepColinAllred
#   EleanorNorton
#   RepDonBacon
#   FrankPallone
#   RepBarragan
#   RepBeatty
#   RepDonaldPayne
#   SpeakerPelosi
#   RepDonBeyer
#   RepPerlmutter
#   SanfordBishop
#   RepDeanPhillips
#   StaceyPlaskett
#   RepDavidEPrice
#   RepMikeQuigley
#   CongBoyle
#   RepRaskin
#   RepKathleenRice
#   RepAnthonyBrown
#   RepShontelBrown
#   RepBrownley
#   RepDeborahRoss
#   RepRoybalAllard
#   RepRaulRuizMD
#   RepCheri
#   RepBobbyRush
#   RepCarbajal
#   RepCardenas
#   RepLindaSanchez
#   RepMGS
#   RepTroyCarter
#   janschakowsky
#   RepSchneider
#   USRepKCastor
#   RepAdamSchiff
#   JoaquinCastrotx
#   CongresswomanSC
#   RepTerriSewell
#   RepKClark
#   RepSherrill
#   repcleaver
#   WhipClyburn
#   GerryConnolly
#   RepSpanberger
#   RepSpeier
#   RepAngieCraig
#   RepCharlieCrist
#   RepDavids
#   RepHaleyStevens
#   RepDean
#   RepDianaDeGette
#   rosadelauro
#   RepMarkTakano
#   repdelgado
#   BennieGThompson
#   RepDeSaulnier
#   RepValDemings
#   RepThompson
#   RepTedDeutch
#   RepLloydDoggett
#   RepSwalwell
#   NormaJTorres
#   RepRitchie
#   RepLoriTrahan
#   RepDavidTrone
#   RepEscobar
#   RepUnderwood
#   RepEspaillat
#   RepJuanVargas
#   RepDwightEvans
#   RepVeasey
#   RepDWStweets
#   RepBillFoster
#   RepFletcher
#   RepLoisFrankel
#   RepWexton
#   RepSusanWild
#   RepNikema
#   RepRubenGallego
#   RepWilson
#   RepJohnYarmuth
#   RepSylviaGarcia
#   RepAlGreen
#   RepJahanaHayes
#   RepBrianHiggins
#   RepHoulahan
#   LeaderHoyer
#
# Communauté 26:
#   SenatorHassan
#   RepChrisPappas
#   RepAnnieKuster
#
# Communauté 27:
#   Rep_Stansbury
#   SenatorLujan
#   MartinHeinrich
#   RepTeresaLF
#
# Communauté 28:
#   RepHuffman
#   SenatorBaldwin
#   RepCori
#   RepJayapal
#   RepAndreCarson
#   RepMondaire
#   RepCasten
#   USRepKeating
#   RepRoKhanna
#   SenDuckworth
#   SenatorDurbin
#   RepJudyChu
#   RepAndyKimNJ
#   RepYvetteClarke
#   BradSherman
#   CongressmanRaja
#   SenFeinstein
#   maziehirono
#   RepLouCorrea
#   RepBarbaraLee
#   RepJasonCrow
#   RepAndyLevin
#   SenatorLeahy
#   RepLowenthal
#   SenMarkey
#   SenatorMenendez
#   RepDebDingell
#   repdinatitus
#   RepRashida
#   RepMaloney
#   ossoff
#   PattyMurray
#   USRepMikeDoyle
#   SenJackReed
#   RepAnnaEshoo
#   SenAlexPadilla
#   SenSanders
#   NydiaVelazquez
#   SenSchumer
#   RepMcEachin
#   RepBrianFitz
#   RepGraceMeng
#   RepBonnie
#   PeterWelch
#   RepGwenMoore
#   RepJoeMorelle
#   RepChuyGarcia
#   SenWarren
#   SenWhitehouse
#   SenatorWarnock
#   RepJimmyGomez
#   RepMarieNewman
#   DonaldNorcross
#   Ilhan
#   RepRaulGrijalva
#   repmarkpocan
#   RepKatiePorter
#   RepPressley
#   RepBourdeaux
#   RepBowman
#
# Communauté 29:
#   RobWittman
#   BobbyScott
#   Kilili_Sablan
#   RepElaineLuria
#   RepJoeCourtney
#
# Communauté 30:
#   RepGonzalez
#   RepTomSuozzi
#   RepJoshG
#   SteveDaines
#   RepGolden
#   SenAngusKing
#
# Communauté 31:
#   chelliepingree
#   BillPascrell
#
# Communauté 32:
#   RepJoshHarder
#   RepOHalleran
#   RepGaramendi
#   RepJimCosta
#   RepDustyJohnson
#
# Communauté 33:
#   RepAdamSmith
#   RepStricklandWA
#   RepRickLarsen
#   RepDelBene
#   RepKimSchrier
#   RepDerekKilmer
#   SenatorCantwell
#
# Communauté 34:
#   RepHuizenga
#   repdarrellissa
#   RepJacobs
#   RepBillJohnson
#   Jim_Jordan
#   RepDaveJoyce
#   RepJohnJoyce
#   RepJohnKatko
#   RepFredKeller
#   MikeKellyPA
#   RepYoungKim
#   RepDavidKustoff
#   boblatta
#   RepLaTurner
#   RepJuliaLetlow
#   USRepLong
#   RepLoudermilk
#   RepFrankLucas
#   RepBlaine
#   RepMalliotakis
#   GOPLeader
#   RepMcCaul
#   PatrickMcHenry
#   RepMeijer
#   RepMeuser
#   RepMMM
#   RepCarolMiller
#   RepBlakeMoore
#   Robert_Aderholt
#   RepTroyNehls
#   RepRickAllen
#   RepNewhouse
#   RepArmstrongND
#   RepArrington
#   RepCindyAxne
#   JayObernolte
#   RepJimBaird
#   RepBalderson
#   USRepGaryPalmer
#   RepJimmyPanetta
#   RepAndyBarr
#   RepBice
#   RepPfluger
#   GReschenthaler
#   RepKevinBrady
#   cathymcmorris
#   RepMikeRogersAL
#   VernBuchanan
#   RepLarryBucshon
#   michaelcburgess
#   RepMikeCarey
#   RepJerryCarl
#   SteveScalise
#   JudgeCarter
#   RepBuddyCarter
#   RepDavid
#   PeteSessions
#   RepSlotkin
#   RepAdrianSmith
#   RepJasonSmith
#   RepSmucker
#   RepJamesComer
#   TomColeOK04
#   RepSpartz
#   RepPeteStauber
#   RepSteel
#   RepStefanik
#   RepBryanSteil
#   RepChrisStewart
#   claudiatenney
#   RepTomEmmer
#   RepMikeTurner
#   RepDavidValadao
#   RepRonEstes
#   RepBethVanDuyne
#   RepPatFallon
#   RepFeenstra
#   RepDrewFerguson
#   RepWalberg
#   RepFischbach
#   michaelgwaltz
#   RepAnnWagner
#   virginiafoxx
#   RepWesterman
#   RepGallagher
#   RepRWilliams
#   RepGarbarino
#   RepMikeGarcia
#   RepLeeZeldin
#   RepTonyGonzales
#   RepKayGranger
#   RepGarretGraves
#   RepMGriffith
#   RepMichaelGuest
#   RepGuthrie
#   RepHerrell
#   RepFrenchHill
#   RepAshleyHinson
#   RepRichHudson
#
# Communauté 35:
#   RepJenniffer
#   RepStephMurphy
#   RepDarrenSoto
#
# Communauté 36:
#   RepBost
#   RepLaHood
#   RodneyDavis
#
# Communauté 37:
#   RepLizCheney
#   RepAuchincloss
#
# Communauté 38:
#   RepMikeLevin
#   RepEdCase
#   RepSteveChabot
#   RepNancyMace
#   RepKarenBass
#   RepBera
#
#
# Communautés détectées dans le graphe dirigé sortant:
# Communauté 1:
#   RepPeterDeFazio
#   RepSchrader
#   RepBonamici
#   SenJeffMerkley
#   RepGregStanton
#   RonWyden
#
# Communauté 2:
#   SenThomTillis
#   SenatorShaheen
#
# Communauté 3:
#   SenJohnThune
#   RoyBlunt
#   SenTinaSmith
#   SenAmyKlobuchar
#   SenBillCassidy
#
# Communauté 4:
#   SenKevinCramer
#   SenJohnHoeven
#
# Communauté 5:
#   SenJohnBarrasso
#   SenatorRisch
#   SenToomey
#   MikeCrapo
#   SenatorTimScott
#   SenCapito
#   CongMikeSimpson
#
# Communauté 6:
#   SenatorWicker
#   SenHydeSmith
#
# Communauté 7:
#   lisamurkowski
#   Sen_JoeManchin
#   SenDanSullivan
#
# Communauté 8:
#   SenatorBennet
#   SenatorHick
#   RepJoeNeguse
#
# Communauté 9:
#   timkaine
#   MarkWarner
#
# Communauté 10:
#   SenCortezMasto
#   SenJackyRosen
#   repdinatitus
#   RepSusieLee
#   RepHorsford
#
# Communauté 11:
#   RepCohen
#   SenatorRomney
#   Call_Me_Dutch
#   SenatorCardin
#   RepJohnCurtis
#   RepKweisiMfume
#   RepSarbanes
#   ChrisVanHollen
#   RepJoeWilson
#   RepMalinowski
#   LindseyGrahamSC
#
# Communauté 12:
#   Rep_Stansbury
#   SenatorLujan
#   MartinHeinrich
#   RepTeresaLF
#
# Communauté 13:
#   RepRonnyJackson
#   RepJacobs
#   RepBillJohnson
#   RepMikeJohnson
#   Jim_Jordan
#   RepFredKeller
#   RepLaMalfa
#   HawleyMO
#   RepDLesko
#   RepThomasMassie
#   RepBrianMast
#   RandPaul
#   RepLisaMcClain
#   RepMcKinley
#   RepMeuser
#   RepMaryMiller
#   RepAlexMooney
#   RepBarryMoore
#   RepMullin
#   Robert_Aderholt
#   RepTroyNehls
#   RepRickAllen
#   RepNewhouse
#   RepRalphNorman
#   RepBrianBabin
#   RepBurgessOwens
#   CongPalazzo
#   RepJimBanks
#   USRepGaryPalmer
#   RepJimBaird
#   RepAndyBiggsAZ
#   RepGusBilirakis
#   RepDanBishop
#   RepBoebert
#   GReschenthaler
#   RepMoBrooks
#   RepTomRice
#   RepJohnRose
#   RepRosendale
#   RepKenBuck
#   RepTedBudd
#   RepChipRoy
#   RepTimBurchett
#   michaelcburgess
#   RepKatCammack
#   RepJerryCarl
#   RepBuddyCarter
#   RepCawthorn
#   AustinScottGA08
#   PeteSessions
#   RepBenCline
#   RepCloudTX
#   Rep_Clyde
#   RepJamesComer
#   RepPeteStauber
#   RepGregSteube
#   WarrenDavidson
#   claudiatenney
#   RepTiffany
#   RepTimmons
#   RepDonaldsPress
#   RepJeffDuncan
#   DrNealDunnFL2
#   RepTomEmmer
#   RepPatFallon
#   RepFischbach
#   RepWalorski
#   RepChuck
#   RepWebster
#   virginiafoxx
#   RepFranklin
#   RepRussFulcher
#   RepMattGaetz
#   rep_stevewomack
#   RepLeeZeldin
#   RepBobGibbs
#   replouiegohmert
#   RepBobGood
#   Lancegooden
#   RepGosar
#   RepKayGranger
#   RepMarkGreen
#   RepMTG
#   RepGrothman
#   RepHarshbarger
#   RepHartzler
#   repkevinhern
#   RepHerrell
#   CongressmanHice
#   RepClayHiggins
#
# Communauté 14:
#   JacksonLeeTX18
#   RepSaraJacobs
#   RepJeffries
#   RepEBJ
#   RepHankJohnson
#   SenBobCasey
#   RepRobinKelly
#   RepDanKildee
#   SenatorFischer
#   RepKirkpatrick
#   RepRonKind
#   JimLangevin
#   RepJohnLarson
#   RepLawrence
#   RepAlLawsonJr
#   RepTedLieu
#   RepMaloney
#   RepSeanMaloney
#   RepKManning
#   RepLucyMcBath
#   BettyMcCollum04
#   RepMcGovern
#   RepGraceMeng
#   RepJerryNadler
#   RepRichardNeal
#   RepAdams
#   RepPeteAguilar
#   RepColinAllred
#   EleanorNorton
#   RepDonBacon
#   RepBarragan
#   RepBeatty
#   RepDonaldPayne
#   SpeakerPelosi
#   RepDonBeyer
#   RepPerlmutter
#   SanfordBishop
#   RepDeanPhillips
#   StaceyPlaskett
#   RepDavidEPrice
#   RepMikeQuigley
#   RepRaskin
#   CongBoyle
#   RepKathleenRice
#   RepAnthonyBrown
#   RepShontelBrown
#   RepBrownley
#   RepDeborahRoss
#   RepRoybalAllard
#   RepRaulRuizMD
#   RepCheri
#   RepBobbyRush
#   RepCarbajal
#   RepMGS
#   RepTroyCarter
#   RepAdamSchiff
#   RepSchneider
#   USRepKCastor
#   JoaquinCastrotx
#   CongresswomanSC
#   RepTerriSewell
#   RepKClark
#   RepYvetteClarke
#   repcleaver
#   BradSherman
#   RepSherrill
#   WhipClyburn
#   GerryConnolly
#   RepSpanberger
#   RepSpeier
#   RepAngieCraig
#   RepDavids
#   RepHaleyStevens
#   RepDean
#   rosadelauro
#   RepMarkTakano
#   repdelgado
#   BennieGThompson
#   RepValDemings
#   RepThompson
#   RepDeSaulnier
#   RepLloydDoggett
#   USRepMikeDoyle
#   RepRitchie
#   RepLoriTrahan
#   RepDavidTrone
#   RepEscobar
#   RepUnderwood
#   RepEspaillat
#   RepDwightEvans
#   RepJuanVargas
#   NydiaVelazquez
#   RepVeasey
#   RepFletcher
#   RepBillFoster
#   RepLoisFrankel
#   RepWexton
#   RepSusanWild
#   RepNikema
#   RepRubenGallego
#   RepWilson
#   RepJohnYarmuth
#   RepSylviaGarcia
#   RepJimmyGomez
#   RepAlGreen
#   RepBrianHiggins
#   RepHoulahan
#   LeaderHoyer
#
# Communauté 15:
#   SenJoniErnst
#   ChuckGrassley
#
# Communauté 16:
#   RepJahanaHayes
#   SenBlumenthal
#   ChrisMurphyCT
#   CoryBooker
#   jahimes
#
# Communauté 17:
#   SenLummis
#   SenGillibrand
#   RepJoeMorelle
#
# Communauté 18:
#   SenTomCotton
#   JohnBoozman
#
# Communauté 19:
#   JerryMoran
#   SenatorTester
#
# Communauté 20:
#   ChrisCoons
#   RepLBR
#   SenatorCarper
#
# Communauté 21:
#   SenatorMenendez
#   SenatorWarnock
#   SenFeinstein
#   ossoff
#   SenAlexPadilla
#
# Communauté 22:
#   SenatorBaldwin
#   RepHuffman
#   RepCori
#   RepJayapal
#   RepMondaire
#   RepAndreCarson
#   janschakowsky
#   RepCasten
#   RepRoKhanna
#   SenDuckworth
#   SenatorDurbin
#   RepAndyKimNJ
#   RepJudyChu
#   CongressmanRaja
#   maziehirono
#   RepLouCorrea
#   RepBarbaraLee
#   RepJasonCrow
#   RepAndyLevin
#   RepDianaDeGette
#   RepLowenthal
#   SenMarkey
#   RepDebDingell
#   RepRashida
#   PattyMurray
#   SenJackReed
#   RepAnnaEshoo
#   SenSanders
#   RepMcEachin
#   SenSchumer
#   RepBonnie
#   RepGwenMoore
#   SenWarren
#   RepChuyGarcia
#   SenWhitehouse
#   RepMarieNewman
#   DonaldNorcross
#   Ilhan
#   FrankPallone
#   RepRaulGrijalva
#   repmarkpocan
#   RepKatiePorter
#   RepPressley
#   RepBourdeaux
#   RepBowman
#
# Communauté 23:
#   senrobportman
#   SenSherrodBrown
#   RepTimRyan
#
# Communauté 24:
#   chelliepingree
#   BillPascrell
#
# Communauté 25:
#   RepAdamSmith
#   RepStricklandWA
#   RepRickLarsen
#   RepKimSchrier
#   RepDelBene
#   RepDerekKilmer
#   SenatorCantwell
#
# Communauté 26:
#   SenMarkKelly
#   SenatorSinema
#
# Communauté 27:
#   RepJenniffer
#   MarioDB
#   RepDarrenSoto
#   RepCharlieCrist
#   RepDWStweets
#   RepMariaSalazar
#   RepStephMurphy
#   RepCarlos
#   RepSires
#
# Communauté 28:
#   RepGolden
#   RepGonzalez
#   SenAngusKing
#   SteveDaines
#
# Communauté 29:
#   VernBuchanan
#   repdarrellissa
#   RepRichHudson
#   RepDavidRouzer
#   RepDustyJohnson
#   RepMikeCarey
#   SteveScalise
#   JudgeCarter
#   RepJohnJoyce
#   MikeKellyPA
#   RepDavid
#   RepYoungKim
#   RepDavidKustoff
#   RepAdrianSmith
#   RepJasonSmith
#   RepSmucker
#   TomColeOK04
#   RepSpartz
#   RepLaTurner
#   boblatta
#   RepSteel
#   RepStefanik
#   RepBryanSteil
#   RepJuliaLetlow
#   RepChrisStewart
#   RepMikeLevin
#   USRepLong
#   RepLoudermilk
#   RepFrankLucas
#   RepMalliotakis
#   GOPLeader
#   RepDavidValadao
#   RepBethVanDuyne
#   RepRonEstes
#   RepDrewFerguson
#   RepWalberg
#   RepWesterman
#   RepCarolMiller
#   RepBlakeMoore
#   RepGaramendi
#   RepMikeGarcia
#   RepGregMurphy
#   RepTonyGonzales
#   RepArmstrongND
#   RepArrington
#   RepOHalleran
#   JayObernolte
#   RepGarretGraves
#   RepBalderson
#   RepMGriffith
#   RepJimmyPanetta
#   RepMichaelGuest
#   RepGuthrie
#   RepBice
#   RepJoshHarder
#   RepPfluger
#   RepKevinBrady
#   cathymcmorris
#
# Communauté 30:
#   RepLarryBucshon
#   marcorubio
#   SenatorBraun
#   SenRonJohnson
#   SenRickScott
#   SenJohnKennedy
#   SenatorLankford
#   SenMikeLee
#   SenTedCruz
#   SenToddYoung
#
# Communauté 31:
#   RepDaveJoyce
#   RepCindyAxne
#   RepFeenstra
#   RepAshleyHinson
#   RepMMM
#
# Communauté 32:
#   RepScottPeters
#   RepPaulTonko
#
# Communauté 33:
#   SenatorHassan
#   RepChrisPappas
#   RepAnnieKuster
#
# Communauté 34:
#   RobWittman
#   BobbyScott
#   Kilili_Sablan
#   RepElaineLuria
#   RepJoeCourtney
#
# Communauté 35:
#   RepMikeRogersAL
#   RepMikeTurner
#   RepMcCaul
#   MarshaBlackburn
#   RepGregoryMeeks
#   RepMeijer
#   michaelgwaltz
#   JohnCornyn
#   RepJohnKatko
#   RepGallagher
#   SenTuberville
#   RepGarbarino
#   RepSlotkin
#   SenatorHagerty
#   JimInhofe
#   RepTedDeutch
#
# Communauté 36:
#   SenatorLeahy
#   PeterWelch
#
# Communauté 37:
#   SenStabenow
#   SenGaryPeters
#
# Communauté 38:
#   DorisMatsui
#   gracenapolitano
#   RepCardenas
#   RepLindaSanchez
#   NormaJTorres
#
# Communauté 39:
#   RepAuchincloss
#   RepJoshG
#   RepJimCosta
#   RepBrianFitz
#   RepTomSuozzi
#   USRepKeating
#   RepSwalwell
#   RepLizCheney
#
# Communauté 40:
#   RepHuizenga
#   PatrickMcHenry
#   RepRWilliams
#   RepBlaine
#   RepAnnWagner
#   RepFrenchHill
#   RepAndyBarr
#
# Communauté 41:
#   RepBost
#   RepLaHood
#   RodneyDavis
#
# Communauté 42:
#   RepEdCase
#   RepSteveChabot
#   RepNancyMace
#   RepKarenBass
#   RepBera

# %%
attributes_df
# Out:
#      congress_member sex  age party chamber
# 0     SenatorBaldwin   F   60     D       S
# 1    SenJohnBarrasso   H   70     R       S
# 2      SenatorBennet   H   60     D       S
# 3    MarshaBlackburn   F   70     R       S
# 4      SenBlumenthal   H   76     D       S
# ..               ...  ..  ...   ...     ...
# 470     RepJoeWilson   H   75     R     Rep
# 471       RobWittman   H   63     R     Rep
# 472  rep_stevewomack   H   65     R     Rep
# 473   RepJohnYarmuth   H   75     R     Rep
# 474     RepLeeZeldin   H   42     R     Rep
#
# [475 rows x 5 columns]

# %%
# Extraire les attributs
data = attributes_df.set_index('congress_member').drop("age",axis=1)

# Définir une fonction pour calculer la cohérence dans une communauté
def analyze_community(community, attribute, attribute_name):
    values = [data.loc[username, attribute] for username in community]
    counts = Counter(values)
    print(f"Cohérence dans la communauté {community_id + 1} pour {attribute_name}:")
    for value, count in counts.items():
        print(f"  {value}: {count/len(community)*100:.2f}% ({count} {value})")
    print()

# Analyser la cohérence dans les communautés
for community_id, community_nodes in enumerate(in_communities):
    # Associer les noms d'utilisateurs aux indices des nœuds
    community = [usernameList[node] for node in community_nodes]
    if len(community) >= 5:
        print(f"Communauté {community_id + 1} ({len(community)} personnes) :")

        # Analyser les attributs (âge, sexe, parti, chambre) dans la communauté
        analyze_community(community, 'age_recode', 'l\'âge')
        analyze_community(community, 'sex', 'le sexe')
        analyze_community(community, 'party', 'le parti')
        analyze_community(community, 'chamber', 'la chambre')
    
    else:
        print(f"Communauté {community_id + 1} est trop petite ({len(community)} personnes), ignorée.")
# Out:
# Communauté 1 est trop petite (2 personnes), ignorée.
# Communauté 2 (5 personnes) :
# Cohérence dans la communauté 2 pour l'âge:
#   70 à 79 ans: 40.00% (2 70 à 79 ans)
#   50 à 59 ans: 60.00% (3 50 à 59 ans)
#
# Cohérence dans la communauté 2 pour le sexe:
#   F: 20.00% (1 F)
#   H: 80.00% (4 H)
#
# Cohérence dans la communauté 2 pour le parti:
#   R: 20.00% (1 R)
#   D: 80.00% (4 D)
#
# Cohérence dans la communauté 2 pour la chambre:
#   S: 80.00% (4 S)
#   Rep: 20.00% (1 Rep)
#
# Communauté 3 est trop petite (2 personnes), ignorée.
# Communauté 4 est trop petite (2 personnes), ignorée.
# Communauté 5 est trop petite (2 personnes), ignorée.
# Communauté 6 est trop petite (2 personnes), ignorée.
# Communauté 7 est trop petite (2 personnes), ignorée.
# Communauté 8 est trop petite (3 personnes), ignorée.
# Communauté 9 (15 personnes) :
# Cohérence dans la communauté 9 pour l'âge:
#   70 à 79 ans: 26.67% (4 70 à 79 ans)
#   60 à 69 ans: 40.00% (6 60 à 69 ans)
#   Plus de 80 ans: 6.67% (1 Plus de 80 ans)
#   50 à 59 ans: 20.00% (3 50 à 59 ans)
#   40 à 49 ans: 6.67% (1 40 à 49 ans)
#
# Cohérence dans la communauté 9 pour le sexe:
#   H: 86.67% (13 H)
#   F: 13.33% (2 F)
#
# Cohérence dans la communauté 9 pour le parti:
#   R: 86.67% (13 R)
#   D: 13.33% (2 D)
#
# Cohérence dans la communauté 9 pour la chambre:
#   S: 93.33% (14 S)
#   Rep: 6.67% (1 Rep)
#
# Communauté 10 est trop petite (2 personnes), ignorée.
# Communauté 11 est trop petite (2 personnes), ignorée.
# Communauté 12 est trop petite (4 personnes), ignorée.
# Communauté 13 est trop petite (2 personnes), ignorée.
# Communauté 14 (6 personnes) :
# Cohérence dans la communauté 14 pour l'âge:
#   70 à 79 ans: 50.00% (3 70 à 79 ans)
#   60 à 69 ans: 33.33% (2 60 à 69 ans)
#   50 à 59 ans: 16.67% (1 50 à 59 ans)
#
# Cohérence dans la communauté 14 pour le sexe:
#   H: 83.33% (5 H)
#   F: 16.67% (1 F)
#
# Cohérence dans la communauté 14 pour le parti:
#   D: 100.00% (6 D)
#
# Cohérence dans la communauté 14 pour la chambre:
#   Rep: 66.67% (4 Rep)
#   S: 33.33% (2 S)
#
# Communauté 15 (11 personnes) :
# Cohérence dans la communauté 15 pour l'âge:
#   70 à 79 ans: 54.55% (6 70 à 79 ans)
#   60 à 69 ans: 36.36% (4 60 à 69 ans)
#   50 à 59 ans: 9.09% (1 50 à 59 ans)
#
# Cohérence dans la communauté 15 pour le sexe:
#   H: 100.00% (11 H)
#
# Cohérence dans la communauté 15 pour le parti:
#   D: 63.64% (7 D)
#   R: 36.36% (4 R)
#
# Cohérence dans la communauté 15 pour la chambre:
#   Rep: 63.64% (7 Rep)
#   S: 36.36% (4 S)
#
# Communauté 16 est trop petite (3 personnes), ignorée.
# Communauté 17 (66 personnes) :
# Cohérence dans la communauté 17 pour l'âge:
#   50 à 59 ans: 39.39% (26 50 à 59 ans)
#   40 à 49 ans: 13.64% (9 40 à 49 ans)
#   60 à 69 ans: 36.36% (24 60 à 69 ans)
#   70 à 79 ans: 4.55% (3 70 à 79 ans)
#   Moins de 40 ans: 6.06% (4 Moins de 40 ans)
#
# Cohérence dans la communauté 17 pour le sexe:
#   H: 86.36% (57 H)
#   F: 13.64% (9 F)
#
# Cohérence dans la communauté 17 pour le parti:
#   R: 100.00% (66 R)
#
# Cohérence dans la communauté 17 pour la chambre:
#   Rep: 96.97% (64 Rep)
#   S: 3.03% (2 S)
#
# Communauté 18 est trop petite (4 personnes), ignorée.
# Communauté 19 est trop petite (4 personnes), ignorée.
# Communauté 20 est trop petite (3 personnes), ignorée.
# Communauté 21 est trop petite (3 personnes), ignorée.
# Communauté 22 est trop petite (4 personnes), ignorée.
# Communauté 23 est trop petite (2 personnes), ignorée.
# Communauté 24 est trop petite (3 personnes), ignorée.
# Communauté 25 (116 personnes) :
# Cohérence dans la communauté 25 pour l'âge:
#   70 à 79 ans: 23.28% (27 70 à 79 ans)
#   Moins de 40 ans: 5.17% (6 Moins de 40 ans)
#   50 à 59 ans: 23.28% (27 50 à 59 ans)
#   Plus de 80 ans: 6.90% (8 Plus de 80 ans)
#   60 à 69 ans: 28.45% (33 60 à 69 ans)
#   40 à 49 ans: 12.93% (15 40 à 49 ans)
#
# Cohérence dans la communauté 25 pour le sexe:
#   F: 46.55% (54 F)
#   H: 53.45% (62 H)
#
# Cohérence dans la communauté 25 pour le parti:
#   D: 95.69% (111 D)
#   R: 4.31% (5 R)
#
# Cohérence dans la communauté 25 pour la chambre:
#   Rep: 98.28% (114 Rep)
#   S: 1.72% (2 S)
#
# Communauté 26 est trop petite (3 personnes), ignorée.
# Communauté 27 est trop petite (4 personnes), ignorée.
# Communauté 28 (60 personnes) :
# Cohérence dans la communauté 28 pour l'âge:
#   50 à 59 ans: 15.00% (9 50 à 59 ans)
#   60 à 69 ans: 25.00% (15 60 à 69 ans)
#   40 à 49 ans: 25.00% (15 40 à 49 ans)
#   Moins de 40 ans: 3.33% (2 Moins de 40 ans)
#   70 à 79 ans: 23.33% (14 70 à 79 ans)
#   Plus de 80 ans: 8.33% (5 Plus de 80 ans)
#
# Cohérence dans la communauté 28 pour le sexe:
#   H: 58.33% (35 H)
#   F: 41.67% (25 F)
#
# Cohérence dans la communauté 28 pour le parti:
#   D: 96.67% (58 D)
#   R: 3.33% (2 R)
#
# Cohérence dans la communauté 28 pour la chambre:
#   Rep: 71.67% (43 Rep)
#   S: 28.33% (17 S)
#
# Communauté 29 (5 personnes) :
# Cohérence dans la communauté 29 pour l'âge:
#   60 à 69 ans: 60.00% (3 60 à 69 ans)
#   70 à 79 ans: 20.00% (1 70 à 79 ans)
#   40 à 49 ans: 20.00% (1 40 à 49 ans)
#
# Cohérence dans la communauté 29 pour le sexe:
#   H: 80.00% (4 H)
#   F: 20.00% (1 F)
#
# Cohérence dans la communauté 29 pour le parti:
#   R: 20.00% (1 R)
#   D: 80.00% (4 D)
#
# Cohérence dans la communauté 29 pour la chambre:
#   Rep: 100.00% (5 Rep)
#
# Communauté 30 (6 personnes) :
# Cohérence dans la communauté 30 pour l'âge:
#   Moins de 40 ans: 16.67% (1 Moins de 40 ans)
#   60 à 69 ans: 33.33% (2 60 à 69 ans)
#   40 à 49 ans: 33.33% (2 40 à 49 ans)
#   70 à 79 ans: 16.67% (1 70 à 79 ans)
#
# Cohérence dans la communauté 30 pour le sexe:
#   H: 100.00% (6 H)
#
# Cohérence dans la communauté 30 pour le parti:
#   R: 33.33% (2 R)
#   D: 66.67% (4 D)
#
# Cohérence dans la communauté 30 pour la chambre:
#   Rep: 66.67% (4 Rep)
#   S: 33.33% (2 S)
#
# Communauté 31 est trop petite (2 personnes), ignorée.
# Communauté 32 (5 personnes) :
# Cohérence dans la communauté 32 pour l'âge:
#   Moins de 40 ans: 20.00% (1 Moins de 40 ans)
#   70 à 79 ans: 60.00% (3 70 à 79 ans)
#   40 à 49 ans: 20.00% (1 40 à 49 ans)
#
# Cohérence dans la communauté 32 pour le sexe:
#   H: 100.00% (5 H)
#
# Cohérence dans la communauté 32 pour le parti:
#   D: 80.00% (4 D)
#   R: 20.00% (1 R)
#
# Cohérence dans la communauté 32 pour la chambre:
#   Rep: 100.00% (5 Rep)
#
# Communauté 33 (7 personnes) :
# Cohérence dans la communauté 33 pour l'âge:
#   50 à 59 ans: 57.14% (4 50 à 59 ans)
#   60 à 69 ans: 28.57% (2 60 à 69 ans)
#   40 à 49 ans: 14.29% (1 40 à 49 ans)
#
# Cohérence dans la communauté 33 pour le sexe:
#   H: 42.86% (3 H)
#   F: 57.14% (4 F)
#
# Cohérence dans la communauté 33 pour le parti:
#   D: 100.00% (7 D)
#
# Cohérence dans la communauté 33 pour la chambre:
#   Rep: 85.71% (6 Rep)
#   S: 14.29% (1 S)
#
# Communauté 34 (99 personnes) :
# Cohérence dans la communauté 34 pour l'âge:
#   50 à 59 ans: 33.33% (33 50 à 59 ans)
#   60 à 69 ans: 29.29% (29 60 à 69 ans)
#   70 à 79 ans: 12.12% (12 70 à 79 ans)
#   Moins de 40 ans: 7.07% (7 Moins de 40 ans)
#   40 à 49 ans: 17.17% (17 40 à 49 ans)
#   Plus de 80 ans: 1.01% (1 Plus de 80 ans)
#
# Cohérence dans la communauté 34 pour le sexe:
#   H: 79.80% (79 H)
#   F: 20.20% (20 F)
#
# Cohérence dans la communauté 34 pour le parti:
#   R: 94.95% (94 R)
#   D: 5.05% (5 D)
#
# Cohérence dans la communauté 34 pour la chambre:
#   Rep: 100.00% (99 Rep)
#
# Communauté 35 est trop petite (3 personnes), ignorée.
# Communauté 36 est trop petite (3 personnes), ignorée.
# Communauté 37 est trop petite (2 personnes), ignorée.
# Communauté 38 (6 personnes) :
# Cohérence dans la communauté 38 pour l'âge:
#   40 à 49 ans: 33.33% (2 40 à 49 ans)
#   70 à 79 ans: 16.67% (1 70 à 79 ans)
#   60 à 69 ans: 33.33% (2 60 à 69 ans)
#   50 à 59 ans: 16.67% (1 50 à 59 ans)
#
# Cohérence dans la communauté 38 pour le sexe:
#   H: 66.67% (4 H)
#   F: 33.33% (2 F)
#
# Cohérence dans la communauté 38 pour le parti:
#   D: 66.67% (4 D)
#   R: 33.33% (2 R)
#
# Cohérence dans la communauté 38 pour la chambre:
#   Rep: 100.00% (6 Rep)

# %% [markdown]
# ### Polarisation du réseau

# %%
# Extraire les attributs
data = attributes_df.set_index('congress_member').drop("age",axis=1)

# Créer un dictionnaire associant les noms d'utilisateurs au parti
party_dict = {username: data.loc[username, 'party'] for username in usernameList}

# Initialiser les compteurs
intra_party_interactions = 0
inter_party_interactions = 0

# Calculer les interactions intra-parti et inter-parti
for i, out_edges in enumerate(outList):
    # Récupérer le parti de l'utilisateur de départ
    source_party = party_dict[usernameList[i]]
    
    for j, target in enumerate(out_edges):
        # Récupérer le parti de l'utilisateur cible
        target_party = party_dict[usernameList[target]]
        
        # Compter les interactions intra-parti et inter-parti
        if source_party == target_party:
            intra_party_interactions += 1
        else:
            inter_party_interactions += 1

# Calculer le ratio des interactions intra-parti aux interactions inter-parti
if inter_party_interactions != 0:
    ratio = intra_party_interactions / inter_party_interactions
    print(f"Ratio des interactions intra-parti aux interactions inter-parti : {ratio:.2f}")
else:
    print("Aucune interaction inter-parti détectée.")

# Interprétation du ratio
if ratio > 1:
    print("Les représentants interagissent plus fréquemment avec les membres de leur propre parti, indiquant une certaine polarisation.")
elif ratio < 1:
    print("Les représentants interagissent plus fréquemment avec les membres d'autres partis, indiquant une polarisation faible.")
else:
    print("Les représentants interagissent également avec les membres de leur propre parti et d'autres partis, indiquant une polarisation moyenne.")
# Out:
# Ratio des interactions intra-parti aux interactions inter-parti : 5.42
# Les représentants interagissent plus fréquemment avec les membres de leur propre parti, indiquant une certaine polarisation.

# %%
# Créer un dictionnaire associant les noms d'utilisateurs au parti
party_dict = {username: data.loc[username, 'party'] for username in usernameList}

# Initialiser un DataFrame pour les interactions entre partis
parties = attributes_df['party'].unique()
interaction_matrix = pd.DataFrame(0, index=parties, columns=parties)

# Calculer les interactions entre les représentants des différents partis
for i, out_edges in enumerate(outList):
    source_party = party_dict[usernameList[i]]
    
    for j, target in enumerate(out_edges):
        target_party = party_dict[usernameList[target]]
        
        # Incrémenter le compteur de la matrice d'interaction
        interaction_matrix.loc[source_party, target_party] += 1

# Créer un graphique de la matrice de confusion des interactions entre partis
plt.figure(figsize=(8, 6))
sns.heatmap(interaction_matrix, annot=True, cmap='coolwarm', fmt='d')
plt.title("Interactions entre représentants des différents partis")
plt.xlabel("Parti cible")
plt.ylabel("Parti source")
plt.show()

# %%
# Créer un dictionnaire associant les noms d'utilisateurs au parti
party_dict = {username: data.loc[username, 'party'] for username in usernameList}

# Initialiser un DataFrame pour les interactions pondérées entre partis
parties = attributes_df['party'].unique()
weighted_interaction_matrix = pd.DataFrame(0, index=parties, columns=parties)

# Calculer les interactions pondérées entre les représentants des différents partis
for i, out_edges in enumerate(outList):
    source_party = party_dict[usernameList[i]]
    
    for j, target in enumerate(out_edges):
        target_party = party_dict[usernameList[target]]
        
        # Obtenir le poids de l'interaction
        weight = outWeight[i][j]
        
        # Ajouter le poids à la matrice d'interactions pondérée
        weighted_interaction_matrix.loc[source_party, target_party] += weight

# Créer un graphique de la matrice d'interactions pondérée entre partis
plt.figure(figsize=(8, 6))
sns.heatmap(weighted_interaction_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Interactions pondérées entre représentants des différents partis")
plt.xlabel("Parti cible")
plt.ylabel("Parti source")
plt.show()

# %%
# Créer un dictionnaire associant les noms d'utilisateurs au parti
party_dict = {username: data.loc[username, 'sex'] for username in usernameList}

# Initialiser un DataFrame pour les interactions entre partis
parties = attributes_df['sex'].unique()
interaction_matrix = pd.DataFrame(0, index=parties, columns=parties)

# Calculer les interactions entre les représentants des différents partis
for i, out_edges in enumerate(outList):
    source_party = party_dict[usernameList[i]]
    
    for j, target in enumerate(out_edges):
        target_party = party_dict[usernameList[target]]
        
        # Incrémenter le compteur de la matrice d'interaction
        interaction_matrix.loc[source_party, target_party] += 1

# Créer un graphique de la matrice de confusion des interactions entre partis
plt.figure(figsize=(8, 6))
sns.heatmap(interaction_matrix, annot=True, cmap='coolwarm', fmt='d')
plt.title("Interactions entre représentants selon le sexe")
plt.xlabel("Parti cible")
plt.ylabel("Parti source")
plt.show()

# %% [markdown]
# ### Structure du réseau

# %%
# Créer un graphe dirigé avec NetworkX
G = nx.DiGraph()

# Ajouter les nœuds et les arêtes avec leurs poids
for i, out_edges in enumerate(outList):
    source = usernameList[i]
    
    for j, target in enumerate(out_edges):
        weight = outWeight[i][j]
        target_user = usernameList[target]
        G.add_edge(source, target_user, weight=weight)

# Calculer la densité du réseau
density = nx.density(G)
print(f"Densité du réseau : {density:.4f}")

# Calculer le diamètre du réseau
if nx.is_strongly_connected(G):
    diameter = nx.diameter(G)
    print(f"Diamètre du réseau : {diameter}")
else:
    print("Le réseau n'est pas fortement connecté, impossible de calculer le diamètre.")

# Calculer la distribution des degrés
in_degrees = [G.in_degree(node) for node in G.nodes()]
out_degrees = [G.out_degree(node) for node in G.nodes()]

# Tracer la distribution des degrés entrants et sortants
plt.figure(figsize=(10, 6))
plt.hist(in_degrees, bins=20, alpha=0.7, label='Degrés entrants')
plt.hist(out_degrees, bins=20, alpha=0.7, label='Degrés sortants')
plt.title("Distribution des degrés entrants et sortants")
plt.xlabel("Degré")
plt.ylabel("Fréquence")
plt.legend()
plt.show()

# Interprétation des caractéristiques topologiques
print("\nInterprétations:")
print(f"1. La densité du réseau est de {density:.4f}, indiquant que le réseau est relativement { 'dense' if density > 0.1 else 'spars'}.")

if nx.is_strongly_connected(G):
    print(f"2. Le diamètre du réseau est de {diameter}, indiquant que la distance maximale entre deux nœuds est { 'petite' if diameter <= 5 else 'grande'}.")
else:
    print("2. Le réseau n'est pas fortement connecté, ce qui signifie qu'il y a des composants faibles (parties déconnectées).")

print("3. La distribution des degrés entrants et sortants montre des pics autour de certains degrés. Cela peut indiquer que certains nœuds ont beaucoup plus ou beaucoup moins de connexions que d'autres, ce qui peut être dû à des rôles spécifiques ou à la notoriété des représentants.")
# Out:
# Densité du réseau : 0.0590
# Le réseau n'est pas fortement connecté, impossible de calculer le diamètre.
# Interprétations:
# 1. La densité du réseau est de 0.0590, indiquant que le réseau est relativement spars.
# 2. Le réseau n'est pas fortement connecté, ce qui signifie qu'il y a des composants faibles (parties déconnectées).
# 3. La distribution des degrés entrants et sortants montre des pics autour de certains degrés. Cela peut indiquer que certains nœuds ont beaucoup plus ou beaucoup moins de connexions que d'autres, ce qui peut être dû à des rôles spécifiques ou à la notoriété des représentants.

# %%
# Créer un graphe dirigé avec NetworkX
G = nx.DiGraph()

# Ajouter les nœuds et les arêtes avec leurs poids
for i, out_edges in enumerate(outList):
    source = usernameList[i]
    
    for j, target in enumerate(out_edges):
        weight = outWeight[i][j]
        target_user = usernameList[target]
        G.add_edge(source, target_user, weight=weight)

# Diviser les représentants par parti, sexe et âge
parties = attributes_df['party'].unique()
sexes = attributes_df['sex'].unique()
ages = attributes_df['age_recode'].unique()

# Fonction pour analyser un segment du réseau
def analyze_segment(segment_nodes, segment_name):
    # Créer un sous-graphe pour le segment
    
    subgraph = G.subgraph(segment_nodes)
    
    # Calculer la densité du sous-graphe
    density = nx.density(subgraph)
    
    # Calculer le diamètre du sous-graphe
    if nx.is_strongly_connected(subgraph):
        diameter = nx.diameter(subgraph)
    else:
        diameter = "Non applicable (sous-graphe non fortement connecté)"
    
    # Calculer la distribution des degrés entrants et sortants
    in_degrees = [subgraph.in_degree(node) for node in subgraph.nodes()]
    out_degrees = [subgraph.out_degree(node) for node in subgraph.nodes()]
    
    # Tracer la distribution des degrés
    plt.figure(figsize=(10, 6))
    plt.hist(in_degrees, bins=20, alpha=0.7, label='Degrés entrants')
    plt.hist(out_degrees, bins=20, alpha=0.7, label='Degrés sortants')
    plt.title(f"Distribution des degrés entrants et sortants - {segment_name}")
    plt.xlabel("Degré")
    plt.ylabel("Fréquence")
    plt.legend()
    plt.show()
    
    # Interprétation des caractéristiques topologiques
    print(f"\nSegment: {segment_name}")
    print(f"1. Densité du segment : {density:.4f}")
    print(f"2. Diamètre du segment : {diameter}")
    print(f"3. La distribution des degrés entrants et sortants montre des pics autour de certains degrés. Cela peut indiquer que certains nœuds ont beaucoup plus ou beaucoup moins de connexions que d'autres.")

# Analyser les segments par parti
for party in parties:
    segment_nodes = data[data['party'] == party].index.tolist()
    analyze_segment(segment_nodes, f"Parti: {party}")

# Analyser les segments par sexe
for sex in sexes:
    segment_nodes = data[data['sex'] == sex].index.tolist()
    analyze_segment(segment_nodes, f"Sexe: {sex}")

# Analyser les segments par tranches d'âge (age_recode)
for age in ages:
    segment_nodes = data[data['age_recode'] == age].index.tolist()
    analyze_segment(segment_nodes, f"Âge: {age}")
# Out:
# Segment: Parti: D
# 1. Densité du segment : 0.0938
# 2. Diamètre du segment : Non applicable (sous-graphe non fortement connecté)
# 3. La distribution des degrés entrants et sortants montre des pics autour de certains degrés. Cela peut indiquer que certains nœuds ont beaucoup plus ou beaucoup moins de connexions que d'autres.
# Segment: Parti: R
# 1. Densité du segment : 0.1068
# 2. Diamètre du segment : Non applicable (sous-graphe non fortement connecté)
# 3. La distribution des degrés entrants et sortants montre des pics autour de certains degrés. Cela peut indiquer que certains nœuds ont beaucoup plus ou beaucoup moins de connexions que d'autres.
# Segment: Sexe: F
# 1. Densité du segment : 0.0905
# 2. Diamètre du segment : Non applicable (sous-graphe non fortement connecté)
# 3. La distribution des degrés entrants et sortants montre des pics autour de certains degrés. Cela peut indiquer que certains nœuds ont beaucoup plus ou beaucoup moins de connexions que d'autres.
# Segment: Sexe: H
# 1. Densité du segment : 0.0584
# 2. Diamètre du segment : Non applicable (sous-graphe non fortement connecté)
# 3. La distribution des degrés entrants et sortants montre des pics autour de certains degrés. Cela peut indiquer que certains nœuds ont beaucoup plus ou beaucoup moins de connexions que d'autres.
# Segment: Âge: 60 à 69 ans
# 1. Densité du segment : 0.0541
# 2. Diamètre du segment : Non applicable (sous-graphe non fortement connecté)
# 3. La distribution des degrés entrants et sortants montre des pics autour de certains degrés. Cela peut indiquer que certains nœuds ont beaucoup plus ou beaucoup moins de connexions que d'autres.
# Segment: Âge: 70 à 79 ans
# 1. Densité du segment : 0.0758
# 2. Diamètre du segment : Non applicable (sous-graphe non fortement connecté)
# 3. La distribution des degrés entrants et sortants montre des pics autour de certains degrés. Cela peut indiquer que certains nœuds ont beaucoup plus ou beaucoup moins de connexions que d'autres.
# Segment: Âge: 50 à 59 ans
# 1. Densité du segment : 0.0773
# 2. Diamètre du segment : Non applicable (sous-graphe non fortement connecté)
# 3. La distribution des degrés entrants et sortants montre des pics autour de certains degrés. Cela peut indiquer que certains nœuds ont beaucoup plus ou beaucoup moins de connexions que d'autres.
# Segment: Âge: 40 à 49 ans
# 1. Densité du segment : 0.0590
# 2. Diamètre du segment : Non applicable (sous-graphe non fortement connecté)
# 3. La distribution des degrés entrants et sortants montre des pics autour de certains degrés. Cela peut indiquer que certains nœuds ont beaucoup plus ou beaucoup moins de connexions que d'autres.
# Segment: Âge: Plus de 80 ans
# 1. Densité du segment : 0.1287
# 2. Diamètre du segment : Non applicable (sous-graphe non fortement connecté)
# 3. La distribution des degrés entrants et sortants montre des pics autour de certains degrés. Cela peut indiquer que certains nœuds ont beaucoup plus ou beaucoup moins de connexions que d'autres.
# Segment: Âge: Moins de 40 ans
# 1. Densité du segment : 0.0736
# 2. Diamètre du segment : Non applicable (sous-graphe non fortement connecté)
# 3. La distribution des degrés entrants et sortants montre des pics autour de certains degrés. Cela peut indiquer que certains nœuds ont beaucoup plus ou beaucoup moins de connexions que d'autres.
